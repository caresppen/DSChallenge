# %% [markdown]
# # Data Science Challenge

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# In first instance, we will play with a sample of the DataFrame to do an EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root_bookings = 'challenge/bookings.csv.bz2'
root_searches = 'challenge/searches.csv.bz2'

# %% [markdown]
# ### Playing with a sample of the data (nrows=10,000)

# %%
df_smp_sch = pd.read_csv(root_searches, sep='^', nrows=10000)
df_smp_sch.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ... Seg6Arrival  \
# 0    TXL         AUH          1           2           TXL  ...         NaN
# 1    ATH         MIL          0           1           ATH  ...         NaN
# 2    ICT         SFO          1           2           ICT  ...         NaN
# 3    RNB         ARN          0           1           RNB  ...         NaN
# 4    OSL         MAD          1           2           OSL  ...         NaN
#
#   Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# 0      NaN         NaN             NaN  1ASIWS                 0
# 1      NaN         NaN             NaN  1ASIWS                 0
# 2      NaN         NaN             NaN  1ASIWS                 0
# 3      NaN         NaN             NaN    1ASI                 0
# 4      NaN         NaN             NaN  1ASIWS                 0
#
#   IsFromInternet IsFromVista                        TerminalID InternetOffice
# 0              0           0  d41d8cd98f00b204e9800998ecf8427e            FRA
# 1              0           0  d41d8cd98f00b204e9800998ecf8427e            KIV
# 2              0           0  d41d8cd98f00b204e9800998ecf8427e            NYC
# 3              0           0  d41d8cd98f00b204e9800998ecf8427e            STO
# 4              0           0  d41d8cd98f00b204e9800998ecf8427e            OSL
#
# [5 rows x 45 columns]

# %%
list(df_smp_sch.columns)
# Out:
# ['Date',
#  'Time',
#  'TxnCode',
#  'OfficeID',
#  'Country',
#  'Origin',
#  'Destination',
#  'RoundTrip',
#  'NbSegments',
#  'Seg1Departure',
#  'Seg1Arrival',
#  'Seg1Date',
#  'Seg1Carrier',
#  'Seg1BookingCode',
#  'Seg2Departure',
#  'Seg2Arrival',
#  'Seg2Date',
#  'Seg2Carrier',
#  'Seg2BookingCode',
#  'Seg3Departure',
#  'Seg3Arrival',
#  'Seg3Date',
#  'Seg3Carrier',
#  'Seg3BookingCode',
#  'Seg4Departure',
#  'Seg4Arrival',
#  'Seg4Date',
#  'Seg4Carrier',
#  'Seg4BookingCode',
#  'Seg5Departure',
#  'Seg5Arrival',
#  'Seg5Date',
#  'Seg5Carrier',
#  'Seg5BookingCode',
#  'Seg6Departure',
#  'Seg6Arrival',
#  'Seg6Date',
#  'Seg6Carrier',
#  'Seg6BookingCode',
#  'From',
#  'IsPublishedForNeg',
#  'IsFromInternet',
#  'IsFromVista',
#  'TerminalID',
#  'InternetOffice']

# %%
df_smp_sch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10000 non-null  object
#  1   Time               10000 non-null  object
#  2   TxnCode            10000 non-null  object
#  3   OfficeID           10000 non-null  object
#  4   Country            10000 non-null  object
#  5   Origin             10000 non-null  object
#  6   Destination        10000 non-null  object
#  7   RoundTrip          10000 non-null  int64
#  8   NbSegments         10000 non-null  int64
#  9   Seg1Departure      10000 non-null  object
#  10  Seg1Arrival        10000 non-null  object
#  11  Seg1Date           9973 non-null   object
#  12  Seg1Carrier        4047 non-null   object
#  13  Seg1BookingCode    1143 non-null   object
#  14  Seg2Departure      7196 non-null   object
#  15  Seg2Arrival        7196 non-null   object
#  16  Seg2Date           7161 non-null   object
#  17  Seg2Carrier        2870 non-null   object
#  18  Seg2BookingCode    998 non-null    object
#  19  Seg3Departure      534 non-null    object
#  20  Seg3Arrival        534 non-null    object
#  21  Seg3Date           531 non-null    object
#  22  Seg3Carrier        517 non-null    object
#  23  Seg3BookingCode    508 non-null    object
#  24  Seg4Departure      440 non-null    object
#  25  Seg4Arrival        440 non-null    object
#  26  Seg4Date           439 non-null    object
#  27  Seg4Carrier        438 non-null    object
#  28  Seg4BookingCode    436 non-null    object
#  29  Seg5Departure      103 non-null    object
#  30  Seg5Arrival        103 non-null    object
#  31  Seg5Date           103 non-null    object
#  32  Seg5Carrier        103 non-null    object
#  33  Seg5BookingCode    103 non-null    object
#  34  Seg6Departure      58 non-null     object
#  35  Seg6Arrival        58 non-null     object
#  36  Seg6Date           58 non-null     object
#  37  Seg6Carrier        58 non-null     object
#  38  Seg6BookingCode    58 non-null     object
#  39  From               9925 non-null   object
#  40  IsPublishedForNeg  10000 non-null  int64
#  41  IsFromInternet     10000 non-null  int64
#  42  IsFromVista        10000 non-null  int64
#  43  TerminalID         10000 non-null  object
#  44  InternetOffice     10000 non-null  object
# dtypes: int64(5), object(40)
# memory usage: 3.4+ MB

# %%
search_col = ['Date', 'Destination']
df_smp_sch = df_smp_sch[search_col]
df_smp_sch.head()
# Out:
#          Date Destination
# 0  2013-01-01         AUH
# 1  2013-01-01         MIL
# 2  2013-01-01         SFO
# 3  2013-01-01         ARN
# 4  2013-01-01         MAD

# %%
df_smp_sch['Date'] = pd.to_datetime(df_smp_sch.Date)
df_smp_sch['year'] = df_smp_sch.Date.dt.year
df_smp_sch['month'] = df_smp_sch.Date.dt.month
df_smp_sch['n'] = 1
df_smp_sch.head()
# Out:
#         Date Destination  year  month  n
# 0 2013-01-01         AUH  2013      1  1
# 1 2013-01-01         MIL  2013      1  1
# 2 2013-01-01         SFO  2013      1  1
# 3 2013-01-01         ARN  2013      1  1
# 4 2013-01-01         MAD  2013      1  1

# %%
df_sch_gr = df_smp_sch.groupby(['Date', 'year', 'month', 'Destination'])['n'].count().reset_index()
df_sch_gr.head()
# Out:
#         Date  year  month Destination  n
# 0 2013-01-01  2013      1         ABT  1
# 1 2013-01-01  2013      1         ABX  1
# 2 2013-01-01  2013      1         ACC  1
# 3 2013-01-01  2013      1         ACE  3
# 4 2013-01-01  2013      1         ADB  1

# %%
# Destination filters: AGP, MAD, BCN
iata_code = ['AGP', 'MAD', 'BCN']
df_smp_filt = df_sch_gr[df_sch_gr.Destination.isin(iata_code)]
df_smp_filt.head()
# Out:
#           Date  year  month Destination   n
# 6   2013-01-01  2013      1         AGP   7
# 24  2013-01-01  2013      1         BCN  26
# 191 2013-01-01  2013      1         MAD  11
# 380 2013-01-02  2013      1         AGP   4
# 395 2013-01-02  2013      1         BCN   9

# %% [markdown]
# First sample plot

# %%
df_AGP = df_smp_filt[df_smp_filt.Destination == 'AGP']
df_MAD = df_smp_filt[df_smp_filt.Destination == 'MAD']
df_BCN = df_smp_filt[df_smp_filt.Destination == 'BCN']

# %%
fig, ax = plt.subplots(figsize=(12,5))

ax = plt.plot(df_AGP.Date, df_AGP.n, label='AGP')
ax = plt.plot(df_MAD.Date, df_MAD.n, label='MAD')
ax = plt.plot(df_BCN.Date, df_BCN.n, label='BCN')

plt.xticks(rotation=15)
plt.legend()

plt.show()

# %% [markdown]
# ### Load the whole dataset

# %% [markdown]
# Creating a function (search_cleaner) to clean the chunks:

# %%
def search_cleaner(data):
    "Cleaner dedicated to shrink the data imported and treated by pd.read_csv"
    import warnings
    warnings.filterwarnings('ignore')
    
    iata_code = ['AGP', 'MAD', 'BCN']
    
    # Cleaning Date columns
    data['Date'] = data.Date.dropna()
    data['Date'] = data[data.Date.str.len() == 10]   # A Date should have no more than 10 characters
    
    data['Date'] = pd.to_datetime(data.Date)
    data['year'] = data.Date.dt.year
    data['month'] = data.Date.dt.month
    data['n'] = 1
    
    # Cleaning the Date column & filtering by year:
    data = data[data.year == 2013]
    
    # Cleaning the arr_port column: strip, dropna, upper
    data['Destination'] = data.Destination.dropna()
    data['Destination'] = data.Destination.str.strip().str.upper()
    
    # Data Wrangling
    data = data.groupby(['Date', 'year', 'month', 'Destination'])['n'].count().reset_index()
    data = data[data.Destination.isin(iata_code)]
    
    return data

# %%
SearchesFile = pd.read_csv(root_searches, usecols=['Date', 'Destination'], sep='^', chunksize=10**6)
chunks = []
loaded_rows = 0
for chunk in SearchesFile:
    loaded_rows += chunk.shape[0]
    cleaned_chunk = search_cleaner(chunk)
    
    chunks.append(cleaned_chunk)
    
    print(cleaned_chunk)
    print("Rows loaded:", loaded_rows)
# Out:
#               Date Destination
# 0       2013-01-01         AUH
# 1       2013-01-01         MIL
# 2       2013-01-01         SFO
# 3       2013-01-01         ARN
# 4       2013-01-01         MAD
# ...            ...         ...
# 999995  2013-10-09         MEL
# 999996  2013-10-09         LAS
# 999997  2013-10-09         AGP
# 999998  2013-10-09         BJS
# 999999  2013-10-09         PAR
#
# [1000000 rows x 2 columns]
#                Date Destination
# 1000000  2013-10-10         YXE
# 1000001  2013-10-10         FLR
# 1000002  2013-10-10         DPS
# 1000003  2013-10-10         KIN
# 1000004  2013-10-10         KTA
# ...             ...         ...
# 1999995  2013-07-24         MSP
# 1999996  2013-07-24         IBZ
# 1999997  2013-07-24         LAX
# 1999998  2013-07-24         CMN
# 1999999  2013-07-24         DFW
#
# [1000000 rows x 2 columns]
#                Date Destination
# 2000000  2013-07-24         MEX
# 2000001  2013-07-24         LON
# 2000002  2013-07-24         CHI
# 2000003  2013-07-24         LHR
# 2000004  2013-07-24         TRS
# ...             ...         ...
# 2999995  2013-05-08         LGW
# 2999996  2013-05-08         LAX
# 2999997  2013-05-08         MAA
# 2999998  2013-05-08         DRW
# 2999999  2013-05-08         DLM
#
# [1000000 rows x 2 columns]
#                Date Destination
# 3000000  2013-05-08         SYD
# 3000001  2013-05-08         PRG
# 3000002  2013-05-08         LAS
# 3000003  2013-05-08         AHB
# 3000004  2013-05-08         DUB
# ...             ...         ...
# 3999995  2013-02-20         MUC
# 3999996  2013-02-20         NAS
# 3999997  2013-02-20         LGA
# 3999998  2013-02-20         IKT
# 3999999  2013-02-20         PAR
#
# [1000000 rows x 2 columns]
#                Date Destination
# 4000000  2013-02-20         MAD
# 4000001  2013-02-20         ALC
# 4000002  2013-02-20         TUN
# 4000003  2013-02-20         FRA
# 4000004  2013-02-20         BKK
# ...             ...         ...
# 4999995  2013-11-29         LAX
# 4999996  2013-11-29         TLV
# 4999997  2013-11-29         MNL
# 4999998  2013-11-29         SIN
# 4999999  2013-11-29         MAD
#
# [1000000 rows x 2 columns]
#                Date Destination
# 5000000  2013-11-29         TYO
# 5000001  2013-11-29         BSB
# 5000002  2013-11-29         PRG
# 5000003  2013-11-29         WDH
# 5000004  2013-11-29         NYC
# ...             ...         ...
# 5999995  2013-09-13         BCN
# 5999996  2013-09-13         MUC
# 5999997  2013-09-13         PAR
# 5999998  2013-09-13         SYD
# 5999999  2013-09-13         MOW
#
# [1000000 rows x 2 columns]
#                Date Destination
# 6000000  2013-09-13         SFO
# 6000001  2013-09-13         ICN
# 6000002  2013-09-13         KWI
# 6000003  2013-09-13         SYD
# 6000004  2013-09-13         MAN
# ...             ...         ...
# 6999995  2013-06-28         LIS
# 6999996  2013-06-28         HER
# 6999997  2013-06-28         BAH
# 6999998  2013-06-28         CDG
# 6999999  2013-06-28         TLV
#
# [1000000 rows x 2 columns]
#                Date Destination
# 7000000  2013-06-28         PUJ
# 7000001  2013-06-28         LON
# 7000002  2013-06-28         CHI
# 7000003  2013-06-28         LCA
# 7000004  2013-06-28         DEL
# ...             ...         ...
# 7999995  2013-04-12         SEA
# 7999996  2013-04-12         EVN
# 7999997  2013-04-12         DEN
# 7999998  2013-04-12         VTE
# 7999999  2013-04-12         CHI
#
# [1000000 rows x 2 columns]
#                Date Destination
# 8000000  2013-04-12         LAX
# 8000001  2013-04-12         LWO
# 8000002  2013-04-12         IST
# 8000003  2013-04-12         AGP
# 8000004  2013-04-12         ARN
# ...             ...         ...
# 8999995  2013-01-25         MCO
# 8999996  2013-01-25         BUF
# 8999997  2013-01-25         EWR
# 8999998  2013-01-25         SGN
# 8999999  2013-01-25         PLS
#
# [1000000 rows x 2 columns]
#                Date Destination
# 9000000  2013-01-25         LON
# 9000001  2013-01-25         YGR
# 9000002  2013-01-25         GVA
# 9000003  2013-01-25         ALC
# 9000004  2013-01-25         SYD
# ...             ...         ...
# 9999995  2013-11-03         POS
# 9999996  2013-11-03         SJC
# 9999997  2013-11-03         SKG
# 9999998  2013-11-03         LGA
# 9999999  2013-11-03         LAX
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 10000000  2013-11-03         CAN
# 10000001  2013-11-03         AUS
# 10000002  2013-11-03         TPE
# 10000003  2013-11-03         LAX
# 10000004  2013-11-03         SIN
# ...              ...         ...
# 10999995  2013-08-18         BKK
# 10999996  2013-08-18         SVQ
# 10999997  2013-08-18         SIN
# 10999998  2013-08-18         LIM
# 10999999  2013-08-18         SSH
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 11000000  2013-08-18         BME
# 11000001  2013-08-18         DPS
# 11000002  2013-08-18         MUC
# 11000003  2013-08-18         VNO
# 11000004  2013-08-18         PAR
# ...              ...         ...
# 11999995  2013-06-02         VIE
# 11999996  2013-06-02         YYZ
# 11999997  2013-06-02         MUC
# 11999998  2013-06-02         CDG
# 11999999  2013-06-02         HNL
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 12000000  2013-06-02         AHB
# 12000001  2013-06-02         SSA
# 12000002  2013-06-02         CDG
# 12000003  2013-06-02         LGW
# 12000004  2013-06-02         OSL
# ...              ...         ...
# 12999995  2013-03-17         PMI
# 12999996  2013-03-17         MIA
# 12999997  2013-03-17         MNL
# 12999998  2013-03-17         HKG
# 12999999  2013-03-17         HHH
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 13000000  2013-03-17         HND
# 13000001  2013-03-17         LAX
# 13000002  2013-03-17         LAX
# 13000003  2013-03-17         SIN
# 13000004  2013-03-17         MGA
# ...              ...         ...
# 13999995  2013-12-24         MOW
# 13999996  2013-12-24         SEA
# 13999997  2013-12-24         ROM
# 13999998  2013-12-24         KRR
# 13999999  2013-12-24         HYD
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 14000000  2013-12-24         WUH
# 14000001  2013-12-24         CLE
# 14000002  2013-12-24         DEL
# 14000003  2013-12-24         KUF
# 14000004  2013-12-24         MEL
# ...              ...         ...
# 14999995  2013-10-08         STO
# 14999996  2013-10-08         VRA
# 14999997  2013-10-08         NYC
# 14999998  2013-10-08         SCW
# 14999999  2013-10-08         OOL
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 15000000  2013-10-08         DEL
# 15000001  2013-10-08         PHX
# 15000002  2013-10-08         CLO
# 15000003  2013-10-08         EAM
# 15000004  2013-10-08         RIO
# ...              ...         ...
# 15999995  2013-07-23         HRG
# 15999996  2013-07-23         CMN
# 15999997  2013-07-23         CPH
# 15999998  2013-07-23         GRZ
# 15999999  2013-07-23         BPS
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 16000000  2013-07-23         FUK
# 16000001  2013-07-23         MDC
# 16000002  2013-07-23         DBV
# 16000003  2013-07-23         KTM
# 16000004  2013-07-23         PVD
# ...              ...         ...
# 16999995  2013-05-07         MBJ
# 16999996  2013-05-07         MIL
# 16999997  2013-05-07         PRG
# 16999998  2013-05-07         BES
# 16999999  2013-05-07         OLB
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 17000000  2013-05-07         JED
# 17000001  2013-05-07         DEL
# 17000002  2013-05-07         MOW
# 17000003  2013-05-07         MPL
# 17000004  2013-05-07         AER
# ...              ...         ...
# 17999995  2013-02-19         LED
# 17999996  2013-02-19         LON
# 17999997  2013-02-19         VIE
# 17999998  2013-02-19         LON
# 17999999  2013-02-19         CUN
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 18000000  2013-02-19         MSY
# 18000001  2013-02-19         RIO
# 18000002  2013-02-19         HEL
# 18000003  2013-02-19         PRG
# 18000004  2013-02-19         BKK
# ...              ...         ...
# 18999995  2013-11-28         FRA
# 18999996  2013-11-28         MUC
# 18999997  2013-11-28         CTA
# 18999998  2013-11-28         MAD
# 18999999  2013-11-28         USM
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 19000000  2013-11-28         SIN
# 19000001  2013-11-28         IZM
# 19000002  2013-11-28         ROC
# 19000003  2013-11-28         SHJ
# 19000004  2013-11-28         MSP
# ...              ...         ...
# 19999995  2013-09-12         BOM
# 19999996  2013-09-12         STO
# 19999997  2013-09-12         TYO
# 19999998  2013-09-12         SSA
# 19999999  2013-09-12         POP
#
# [1000000 rows x 2 columns]
#                 Date Destination
# 20000000  2013-09-12         ORD
# 20000001  2013-09-12         PER
# 20000002  2013-09-12         DUS
# 20000003  2013-09-12         VCE
# 20000004  2013-09-12         SIN
# ...              ...         ...
# 20390193  2013-10-13         NBO
# 20390194  2013-10-13         ALA
# 20390195  2013-10-13         LHR
# 20390196  2013-10-13         MAD
# 20390197  2013-10-13          HA
#
# [390198 rows x 2 columns]

# %%
df_sch = pd.concat(chunks)
df_sch.head()
# Out:
#           Date    year  month Destination   n
# 6   2013-01-01  2013.0    1.0         AGP  21
# 24  2013-01-01  2013.0    1.0         BCN  78
# 191 2013-01-01  2013.0    1.0         MAD  33
# 380 2013-01-02  2013.0    1.0         AGP  12
# 395 2013-01-02  2013.0    1.0         BCN  27

# %%
df_sch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22575 entries, 6 to 140012
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         22575 non-null  datetime64[ns]
#  1   year         22575 non-null  float64
#  2   month        22575 non-null  float64
#  3   Destination  22575 non-null  object
#  4   n            22575 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
df_sch['year'], df_sch['month'] = df_sch.year.astype(int), df_sch.month.astype(int)

# %%
df_AGP = df_sch[df_sch.Destination == 'AGP']
df_AGP.sample(5)
# Out:
#              Date  year  month Destination   n
# 124743 2013-11-17  2013     11         AGP   6
# 47712  2013-05-06  2013      5         AGP  15
# 69166  2013-06-29  2013      6         AGP   9
# 91456  2013-08-24  2013      8         AGP  12
# 136325 2013-12-16  2013     12         AGP   9

# %%
df_gr = df_sch.groupby(['Date', 'Destination', 'month'])['n'].sum().reset_index()
df_gr.head()
# Out:
#         Date Destination  month     n
# 0 2013-01-01         AGP      1   399
# 1 2013-01-01         BCN      1  1482
# 2 2013-01-01         MAD      1   660
# 3 2013-01-02         AGP      1   228
# 4 2013-01-02         BCN      1   513

# %%
df_gr.groupby(['month', 'Destination'])['n'].count()
# Out:
# month  Destination
# 1      AGP            31
#        BCN            31
#        MAD            31
# 2      AGP            28
#        BCN            28
#        MAD            28
# 3      AGP            31
#        BCN            31
#        MAD            31
# 4      AGP            30
#        BCN            30
#        MAD            30
# 5      AGP            31
#        BCN            31
#        MAD            31
# 6      AGP            30
#        BCN            30
#        MAD            30
# 7      AGP            31
#        BCN            31
#        MAD            31
# 8      AGP            31
#        BCN            31
#        MAD            31
# 9      AGP            30
#        BCN            30
#        MAD            30
# 10     AGP            31
#        BCN            31
#        MAD            31
# 11     AGP            30
#        BCN            30
#        MAD            30
# 12     AGP            23
#        BCN            25
#        MAD            25
# Name: n, dtype: int64

# %% [markdown]
# ### Plot the monthly number of searches for flights arriving at Málaga, Madrid or Barcelona
# Plot a curve for each city in the same figure

# %%
df_AGP = df_gr[df_gr.Destination == 'AGP']
df_MAD = df_gr[df_gr.Destination == 'MAD']
df_BCN = df_gr[df_gr.Destination == 'BCN']

# %%
plt.style.use('tableau-colorblind10')

fig, ax = plt.subplots(figsize=(25,8))

ax = plt.plot(df_AGP.Date, df_AGP.n, label='AGP')
ax = plt.plot(df_MAD.Date, df_MAD.n, label='MAD')
ax = plt.plot(df_BCN.Date, df_BCN.n, label='BCN')

plt.legend()
plt.title('Daily number of searches for flights arriving at Malaga (AGP), Madrid (MAD) and Barcelona (BCN)')
plt.xlabel('Date')
plt.ylabel('Number of searches')

plt.show()

# %% [markdown]
# Let's have a look at the data at a more global view, using months. In this way it will be easier to take conclusions

# %%
def autolabel(splot):
    for p in splot.patches:
        height = p.get_height().astype(int)
        splot.annotate('{:,}'.format(height),
                       xy = (p.get_x() + p.get_width() / 2, height),
                       ha = 'center',
                       va = 'center',
                       xytext = (0, 10),
                       textcoords = 'offset points')

# %%
df_AGP.head()
# Out:
#          Date Destination  month    n
# 0  2013-01-01         AGP      1  399
# 3  2013-01-02         AGP      1  228
# 6  2013-01-03         AGP      1  285
# 9  2013-01-04         AGP      1  285
# 12 2013-01-05         AGP      1  228

# %%
df_sns = df_gr.groupby(['month', 'Destination'])['n'].sum().reset_index()
df_sns.head()
# Out:
#    month Destination      n
# 0      1         AGP   9633
# 1      1         BCN  29469
# 2      1         MAD  24258
# 3      2         AGP   8379
# 4      2         BCN  28329

# %%
plt.style.use('tableau-colorblind10')

fig, ax = plt.subplots(figsize=(25,8))

splot = sns.barplot(data=df_sns, x='month', y='n', hue='Destination', ci=None)

ax.legend()
ax.set_title('Monthly number of searches for flights arriving at Malaga (AGP), Madrid (MAD) and Barcelona (BCN)')
ax.set_xlabel('Month')
ax.set_ylabel('Number of searches')
ax.set_yticks([])
autolabel(splot)

plt.show()
